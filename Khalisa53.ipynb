# %% [markdown]
# <a href="https://colab.research.google.com/github/khalisazalfasalsabila/Re202-pemrograman-pertemuan-1/blob/main/Khalisa53.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Variables**

# %%
nama = "Khalisa"
umur = 19
is_student = True

print("Nama:", nama)
print("Umur:", umur)
print("Mahasiswa:", is_student)
# Out:
# Nama: Khalisa
# Umur: 19
# Mahasiswa: True

# %% [markdown]
# python juga bisa menetapkan nilai ke beberapa variabel dalam satu baris

# %%
a, b, c = 10, 20, 30
print(a, b, c)

x = y = z = "Risaya"
print(x, y, z)
# Out:
# 10 20 30
# Risaya Risaya Risaya

# %% [markdown]
# kita juga bisa menggunakan operator "+" untuk output yang multipel variabel

# %%
x = "Yesaya "
y = "Situmorang"

print(x+y)
# Out:
# Yesaya Situmorang

# %%
a = "joko "
b = "anwar"
c = a+b

print(c)
# Out:
# joko anwar

# %%
x = "Rizky"
y = " Putra "
z = "Ramadhan"

print (x+y+z)
# Out:
# Rizky Putra Ramadhan

# %% [markdown]
# **OPERATORS**

# %%
print(10+5)
# Out:
# 15

# %% [markdown]
# Operator Aritmatika

# %%
a = 10
b = 3

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a % b)
print(a ** b)
print(a // b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1
# 1000
# 3

# %% [markdown]
# operator penugasaan

# %%
x = 10
x += 5
print(x)
# Out:
# 15

# %%
y = 20
y //= 3
print(y)
# Out:
# 6

# %%
x = 10
x &= 3
print(x)
# Out:
# 2

# %% [markdown]
# Operator Perbandingan

# %%
a = 5
b = 10

print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# Operator Logika

# %%
x = 7
y = 12

print(x > 5 and y < 15)
print(x > 10 or y < 15)
print(not(x > 5))
# Out:
# True
# True
# False

# %% [markdown]
# Operator Keanggotaan

# %%
buah = ["apel", "mangga", "jeruk"]
print("apel" in buah)
print("pisang" not in buah)
# Out:
# True
# True

# %% [markdown]
# **Primitive Data Types**

# %% [markdown]
# Int

# %%
x = 150
y = 30

print(x)
print(y)
# Out:
# 150
# 30

# %%
x = 150
y = 30

print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# Float

# %%
x = 1.10
y = 1.0
z = -35.59

print(type(z))
print(y)
# Out:
# <class 'float'>
# 1.0

# %% [markdown]
# Complex

# %%
z = 3 + 4j
print(z)
print(z.real)
print(z.imag)
# Out:
# (3+4j)
# 3.0
# 4.0

# %% [markdown]
# String

# %%
a = "Hello world"

print(a)
print(type(a))
# Out:
# Hello world
# <class 'str'>

# %% [markdown]
# Boolean

# %%
a = True
b = False
print(a)
print(b)
# Out:
# True
# False

# %% [markdown]
# Non-Primitive Data Types

# %% [markdown]
# List

# %%
huruf = ["a", "b", "c", "d", "e", "f"]

print(huruf[1:4])
# Out:
# ['b', 'c', 'd']

# %%
numbers = [1, 2, 3, 4, 5]

mixed = [10, "Python", 3.14, True]

print(numbers)
print(mixed)
# Out:
# [1, 2, 3, 4, 5]
# [10, 'Python', 3.14, True]

# %% [markdown]
# Mnegakses Elemen List

# %%
fruits = ["Apple", "Banana", "Cherry"]

print(fruits[0])
print(fruits[1])
print(fruits[-1])
# Out:
# Apple
# Banana
# Cherry

# %% [markdown]
# Mengubah Elemen List

# %%
fruits[1] = "Mango"
print(fruits)
# Out:
# ['Apple', 'Mango', 'Cherry']

# %% [markdown]
# Menambahkan Elemen ke List

# %%
fruits.append("Orange")
print(fruits)

fruits.insert(1, "Grapes")
print(fruits)
# Out:
# ['Apple', 'Mango', 'Cherry', 'Orange']
# ['Apple', 'Grapes', 'Mango', 'Cherry', 'Orange']

# %% [markdown]
# Menghapus Elemen List

# %%
fruits.remove("Mango")
print(fruits)

fruits.pop(2)
print(fruits)

del fruits[1]
print(fruits)
# Out:
# ['Apple', 'Grapes', 'Cherry', 'Orange']
# ['Apple', 'Grapes', 'Orange']
# ['Apple', 'Orange']

# %% [markdown]
# Menggunakan Loop pada List

# %%
for fruit in fruits:
    print(fruit)
# Out:
# Apple
# Orange

# %% [markdown]
# Kesimpulan:
#
# List menyimpan banyak nilai dalam satu variabel
# Bisa diakses, diubah, ditambah, dan dihapus
# Loop dan List Comprehension membuatnya lebih fleksibel

# %% [markdown]
# **TUPLE**

# %%
numbers = (1, 2, 3, 4, 5)

mixed = (10, "Python", 3.14, True)

print(numbers)
print(mixed)
# Out:
# (1, 2, 3, 4, 5)
# (10, 'Python', 3.14, True)

# %% [markdown]
# Jika hanya satu elemen dalam tuple, tambahkan koma , agar Python mengenali sebagai tuple.

# %%
single_element = (5,)
not_tuple = (5)

print(type(single_element))
print(type(not_tuple))
# Out:
# <class 'tuple'>
# <class 'int'>

# %% [markdown]
# Mengakses Elemen Tuple

# %%
fruits = ("Apple", "Banana", "Cherry")

print(fruits[0])
print(fruits[-1])
# Out:
# Apple
# Cherry

# %% [markdown]
# Tuple tidak bisa diubah jika sudah dibuat, contoh:
#
# tidak seperti list yang bisa diubah

# %%
fruits[2] = "Mango"

print(fruits)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_952/763814802.py in <cell line: 0>()
# ----> 1 fruits[2] = "Mango"
#       2
#       3 print(fruits)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Bisa Menyimpan Banyak Nilai Sekaligus (Packing & Unpacking)

# %%
data = ("Ezha", 21, "Data Scientist")

name, age, job = data

print(name)
print(age)
print(job)
# Out:
# Ezha
# 21
# Data Scientist

# %% [markdown]
# Menggabungkan Tuple

# %%
tuple1 = (1, 2, 3)
tuple2 = (4, 5, 6)

new_tuple = tuple1 + tuple2
print(new_tuple)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# Menghitung Elemen dalam Tuple

# %%
numbers = (1, 2, 2, 3, 4, 2, 5)

print(numbers.count(2))
print(numbers.index(5))
# Out:
# 3
# 6

# %% [markdown]
# Kesimpulan:
#
# Tuple mirip list, tetapi immutable (tidak bisa diubah).
# Lebih cepat dan aman dibanding list jika datanya tetap.
# Bisa digunakan untuk menyimpan data yang tidak boleh berubah.

# %% [markdown]
# **Hands On**

# %%
Hands On
# Out:
#   File "/tmp/ipykernel_952/838609640.py", line 1
#     Hands On
#           ^
# SyntaxError: invalid syntax

# %%
lokasi[0] = 15.0  # Apakah ini berhasil?
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_952/621390748.py in <cell line: 0>()
# ----> 1 lokasi[0] = 15.0  # Apakah ini berhasil?
#
# NameError: name 'lokasi' is not defined

# %% [markdown]
# Dictionary
# Membuat Dictionary

# %%
student = {
    "nama": "Khalisa Zalfa Salzabila",
    "umur": 19,
    "jurusan": "electronika"

}

print(student)
# Out:
# {'nama': 'Khalisa Zalfa Salzabila', 'umur': 19, 'jurusan': 'electronika'}

# %% [markdown]
# Dictionary menggunakan kurung kurawal {}.
#
# Mengakses Nilai dalam Dictionary

# %%
print(student["nama"])
print(student["umur"])
# Out:
# Khalisa Zalfa Salzabila
# 19

# %% [markdown]
# Menambahkan atau Mengubah Data dalam Dictionary

# %%
student["alamat"] = "Batam"

student["umur"] = 19

print(student)
# Out:
# {'nama': 'Khalisa Zalfa Salzabila', 'umur': 19, 'jurusan': 'electronika', 'alamat': 'Batam'}

# %% [markdown]
# menghapus elemen dalam dictionary

# %%
del student["jurusan"]

umur = student.pop("umur")

print(student)
print(umur)
# Out:
# {'nama': 'Khalisa Zalfa Salzabila', 'alamat': 'Batam'}
# 19

# %% [markdown]
# Fungsi pop() pada dictionary digunakan untuk menghapus sebuah key dan mengembalikan nilai (value) yang dihapus. sedangkan "del" hanya menghapus tanpa menyimpan nilai

# %% [markdown]
# SET

# %%
angka = {1, 2, 3, 2, 4, 5}

huruf = {"a", "b", "c", "d"}

campuran = {1, "Python", 3.14}

print(angka)
print(huruf)
print(campuran)
# Out:
# {1, 2, 3, 4, 5}
# {'c', 'b', 'd', 'a'}
# {'Python', 1, 3.14}

# %% [markdown]
# Ciri-ciri set:
#
# Tidak ada elemen yang duplikat
# Tidak memiliki indeks (tidak bisa diakses dengan angka index seperti list)
# Menghapus Duplikat dari List dengan Set

# %%
angka_list = [1, 2, 2, 3, 4, 4, 5]
angka_set = set(angka_list)

print(angka_set)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# Menambah dan Menghapus Elemen Menggunakan Set

# %%
angka.add(6)
angka.remove(3)
print(angka)
# Out:
# {1, 2, 4, 5, 6}

# %% [markdown]
# Operasi Himpunan (set operations) Irisan (Intersection)

# %%
a = {1, 2, 3, 4}
b = {3, 4, 5, 6}

print(a & b)
# Out:
# {3, 4}

# %% [markdown]
# Gabungan atau Union

# %%
print(a | b)
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# Selisih (Difference)

# %%
print(a - b)
print(b - a)
# Out:
# {1, 2}
# {5, 6}

# %% [markdown]
# Kesimpulan
#
# set digunakan untuk menyimpan elemen unik
# Tidak memiliki indeks atau urutan tetap
# Cocok untuk operasi himpunan (union, intersection, dll.)
# Berguna untuk menghapus duplikat dari list

# %%
id_pengguna = {101, 202, 303, 404}

print("Sebelum ditambah:", id_pengguna)
# Out:
# Sebelum ditambah: {202, 404, 101, 303}

# %% [markdown]
# Hands on

# %% [markdown]
# Jika saya ingin menambahkan
#
# id_pengguna.add(505) dan
# id_pengguna.add(101) apa yang terjadi?

# %%
id_pengguna.add(505)
print("Setelah ditambah:", id_pengguna)
# Out:
# Setelah ditambah: {101, 202, 303, 404, 505}

# %%
id_pengguna.add(101)
print("Setelah ditambah:", id_pengguna)
# Out:
# Setelah ditambah: {101, 202, 303, 404, 505}

# %% [markdown]
# Konversi Tipe Data
# Konversi Otomatis (Implicit Conversion)

# %%
angka_int = 10
angka_float = angka_int + 3.5

print(angka_float)
print(type(angka_float))
# Out:
# 13.5
# <class 'float'>

# %% [markdown]
# Python mengubah 10 (int) menjadi 10.0 (float) agar sesuai dengan operasi float.
#
# Konversi Manual (Explicit Conversion)
#
# int ke float / float ke int

# %%
x = 5
x_float = float(x)

y = 7.8
y_int = int(y)

print(x_float)
print(y_int)
# Out:
# 5.0
# 7

# %% [markdown]
# int/float ke string

# %%
ngka = 42
angka_str = str(angka)

teks = "100"
teks_int = int(teks)

print(angka_str, type(angka_str))
print(teks_int, type(teks_int))
# Out:
# {1, 2, 4, 5, 6} <class 'str'>
# 100 <class 'int'>

# %% [markdown]
# list ke tuple

# %%
data_list = [1, 2, 3]
data_tuple = tuple(data_list)
data_tuple2 = (4, 5, 6)
data_list2 = list(data_tuple2)

print(data_tuple, type(data_tuple))
print(data_list2, type(data_list2))
# Out:
# (1, 2, 3) <class 'tuple'>
# [4, 5, 6] <class 'list'>

# %% [markdown]
# list/tuple ke set

# %%
angka_list = [1, 2, 2, 3]
angka_set = set(angka_list)

angka_tuple = tuple(angka_set)

print(angka_set)
print(angka_tuple)
# Out:
# {1, 2, 3}
# (1, 2, 3)

# %% [markdown]
# Dictionary ke Lis

# %%
data_dict = {"nama": "Riccy", "umur": 17}

keys_list = list(data_dict.keys())

values_list = list(data_dict.values())

print(keys_list)
print(values_list)
# Out:
# ['nama', 'umur']
# ['Riccy', 17]

# %% [markdown]
# Kesimpulan:
#
# 1. Konversi Otomatis terjadi saat Python perlu menyamakan tipe data dalam operasi.
# 2. Konversi Manual (Casting) dilakukan dengan fungsi bawaan (int(), float(), str(), list(), dll.).
# 3. Gunakan konversi yang tepat sesuai kebutuhan, terutama untuk menghindari error saat operasi antar tipe data.
